# %% [markdown]
# # Explores Weather Information in the US

# %% [markdown]
# Clean Data

# %%
with open("artifacts/ghcnd-stations.txt") as bad_stations, open("artifacts/ghcnd-stations-fixed.txt", 'w+') as good_stations:
    for b in bad_stations:
        good_stations.write("[" + '[,['.join(b[:74].split(None, 4)) + "[")
        good_stations.write("\n")

# %% [markdown]
# Read Data

# %%
import pandas as pd
import numpy as np

# https://www.ncei.noaa.gov/data/global-historical-climatology-network-daily/doc/GHCND_documentation.pdf
with open("artifacts/ghcnd-stations-fixed.txt") as reader:
    ghcnd_stations = pd.read_csv(
        reader,
        header=None,
        quotechar='[',
        sep=',',
        names=["station_id", "latitude", "longitude", "elevation_above_sea_level", "station_name"]
    )

ghcnd_stations
# Out:
#          station_id  latitude  longitude  elevation_above_sea_level  \
# 0       ACW00011604   17.1167   -61.7833                       10.1
# 1       ACW00011647   17.1333   -61.7833                       19.2
# 2       AE000041196   25.3330    55.5170                       34.0
# 3       AEM00041194   25.2550    55.3640                       10.4
# 4       AEM00041217   24.4330    54.6510                       26.8
# ...             ...       ...        ...                        ...
# 118487  ZI000067969  -21.0500    29.3670                      861.0
# 118488  ZI000067975  -20.0670    30.8670                     1095.0
# 118489  ZI000067977  -21.0170    31.5830                      430.0
# 118490  ZI000067983  -20.2000    32.6160                     1132.0
# 118491  ZI000067991  -22.2170    30.0000                      457.0
#
#                              station_name
# 0       ST JOHNS COOLIDGE FLD
# 1       ST JOHNS
# 2       SHARJAH INTER. AIRP            GS
# 3       DUBAI INTL
# 4       ABU DHABI INTL
# ...                                   ...
# 118487  WEST NICHOLSON
# 118488  MASVINGO
# 118489  BUFFALO RANGE
# 118490  CHIPINGE                       GS
# 118491  BEITBRIDGE
#
# [118492 rows x 5 columns]

# %% [markdown]
# Filter only US weather stations.

# %%
ghcnd_stations.query("station_id == 'US1WAKG0196'")
# Out:
#         station_id  latitude  longitude  elevation_above_sea_level  \
# 89111  US1WAKG0196   47.3539  -122.3181                       94.8
#
#                                station_name
# 89111  WA DES MOINES 2.9 S

# %%
us_stations = ghcnd_stations[ghcnd_stations['station_id'].str.startswith('US')]
us_stations
# Out:
#          station_id  latitude  longitude  elevation_above_sea_level  \
# 52532   US009052008   43.7333   -96.6333                      482.0
# 52533   US10RMHS145   40.5268  -105.1113                     1569.1
# 52534   US10adam001   40.5680   -98.5069                      598.0
# 52535   US10adam002   40.5093   -98.5493                      601.1
# 52536   US10adam003   40.4663   -98.6537                      615.1
# ...             ...       ...        ...                        ...
# 117697  USW00096405   60.4731  -145.3542                       25.3
# 117698  USW00096406   64.5014  -154.1297                       78.9
# 117699  USW00096407   66.5620  -159.0036                        6.7
# 117700  USW00096408   63.4519  -150.8747                      678.2
# 117701  USW00096409   68.6483  -149.3986                      750.1
#
#                                 station_name
# 52532   SD SIOUX FALLS (ENVIRON. CANADA)
# 52533   CO RMHS 1.6 SSW
# 52534   NE JUNIATA 1.5 S
# 52535   NE JUNIATA 6.0 SSW
# 52536   NE HOLSTEIN 0.1 NW
# ...                                      ...
# 117697  AK CORDOVA 14 ESE
# 117698  AK RUBY 44 ESE
# 117699  AK SELAWIK 28 E
# 117700  AK DENALI 27 N
# 117701  AK TOOLIK LAKE 5 ENE
#
# [65170 rows x 5 columns]

# %% [markdown]
# Reusable functions.

# %%
def coordinate_msg(latitude: float, longitude: float):
    if latitude > 0:
        latitude_msg = f"{latitude}°N"
    elif latitude < 0:
        latitude_msg = f"{abs(latitude)}°S"
    else:
        latitude_msg = "0°"

    if longitude > 0:
        longitude_msg = f"{longitude}°E"
    elif longitude < 0:
        longitude_msg = f"{abs(longitude)}°W"
    else:
        longitude_msg = "0°"


    return ','.join([latitude_msg, longitude_msg])

# %% [markdown]
# For each of the weather stations, pick the closest zip code.

# %%
from uszipcode import SearchEngine


def find_closest_zip_code(latitude: float, longitude: float):
    search = SearchEngine()
    result = search.by_coordinates(lat=latitude, lng=longitude, radius=5)

    if len(result) == 0:
        return pd.NA
    else:
        return result[0].zipcode
    

us_stations['zip_code'] =  np.vectorize(find_closest_zip_code)(us_stations['latitude'], us_stations['longitude'])
us_stations
# Out:
# /var/folders/44/y4yg1dfd20sg9qvqvp_3djc40000gn/T/ipykernel_32653/1598789507.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_stations['zip_code'] =  np.vectorize(find_closest_zip_code)(us_stations['latitude'], us_stations['longitude'])
#          station_id  latitude  longitude  elevation_above_sea_level  \
# 52532   US009052008   43.7333   -96.6333                      482.0
# 52533   US10RMHS145   40.5268  -105.1113                     1569.1
# 52534   US10adam001   40.5680   -98.5069                      598.0
# 52535   US10adam002   40.5093   -98.5493                      601.1
# 52536   US10adam003   40.4663   -98.6537                      615.1
# ...             ...       ...        ...                        ...
# 117697  USW00096405   60.4731  -145.3542                       25.3
# 117698  USW00096406   64.5014  -154.1297                       78.9
# 117699  USW00096407   66.5620  -159.0036                        6.7
# 117700  USW00096408   63.4519  -150.8747                      678.2
# 117701  USW00096409   68.6483  -149.3986                      750.1
#
#                                 station_name zip_code
# 52532   SD SIOUX FALLS (ENVIRON. CANADA)         <NA>
# 52533   CO RMHS 1.6 SSW                         80526
# 52534   NE JUNIATA 1.5 S                        68955
# 52535   NE JUNIATA 6.0 SSW                      68973
# 52536   NE HOLSTEIN 0.1 NW                      68950
# ...                                      ...      ...
# 117697  AK CORDOVA 14 ESE                        <NA>
# 117698  AK RUBY 44 ESE                           <NA>
# 117699  AK SELAWIK 28 E                          <NA>
# 117700  AK DENALI 27 N                           <NA>
# 117701  AK TOOLIK LAKE 5 ENE                     <NA>
#
# [65170 rows x 6 columns]

# %% [markdown]
# Filter where Zip Code is NA

# %%
us_stations_all_zip = us_stations[us_stations['zip_code'].notna()]
us_stations_all_zip
# Out:
#          station_id  latitude  longitude  elevation_above_sea_level  \
# 52533   US10RMHS145   40.5268  -105.1113                     1569.1
# 52534   US10adam001   40.5680   -98.5069                      598.0
# 52535   US10adam002   40.5093   -98.5493                      601.1
# 52536   US10adam003   40.4663   -98.6537                      615.1
# 52537   US10adam004   40.4798   -98.4026                      570.0
# ...             ...       ...        ...                        ...
# 117691  USW00094992   47.7472   -90.3444                      185.9
# 117692  USW00094993   45.6689   -96.9914                      353.9
# 117693  USW00094994   43.1561   -90.6775                      204.8
# 117694  USW00094995   40.8483   -96.5650                      362.4
# 117695  USW00094996   40.6953   -96.8542                      418.2
#
#                                 station_name zip_code
# 52533   CO RMHS 1.6 SSW                         80526
# 52534   NE JUNIATA 1.5 S                        68955
# 52535   NE JUNIATA 6.0 SSW                      68973
# 52536   NE HOLSTEIN 0.1 NW                      68950
# 52537   NE AYR 3.5 NE                           68925
# ...                                      ...      ...
# 117691  MN GRAND MARAIS                         55604
# 117692  SD SISSETON MUNI AP                     57262
# 117693  WI BOSCOBEL AP                          53805
# 117694  NE LINCOLN 8 ENE                        68527
# 117695  NE LINCOLN 11 SW                        68339
#
# [49051 rows x 6 columns]

# %%
us_stations_all_zip.station_id.to_list()
# Out:
# ['US10RMHS145',
#  'US10adam001',
#  'US10adam002',
#  'US10adam003',
#  'US10adam004',
#  'US10adam006',
#  'US10adam007',
#  'US10adam008',
#  'US10adam010',
#  'US10adam011',
#  'US10adam012',
#  'US10adam015',
#  'US10adam016',
#  'US10adam019',
#  'US10adam022',
#  'US10adam023',
#  'US10adam025',
#  'US10adam027',
#  'US10adam028',
#  'US10adam029',
#  'US10adam032',
#  'US10adam034',
#  'US10adam035',
#  'US10adam036',
#  'US10adam039',
#  'US10adam041',
#  'US10adam043',
#  'US10adam045',
#  'US10adam046',
#  'US10adam047',
#  'US10adam051',
#  'US10adam053',
#  'US10adam054',
#  'US10adam056',
#  'US10ante003',
#  'US10bann006',
#  'US10bann007',
#  'US10blai004',
#  'US10blai012',
#  'US10boon004',
#  'US10boon005',
#  'US10boon006',
#  'US10boon008',
#  'US10boon011',
#  'US10box_005',
#  'US10box_006',
#  'US10box_008',
#  'US10box_013',
#  'US10box_020',
#  'US10box_024',
#  'US10boyd002',
#  'US10boyd003',
#  'US10boyd005',
#  'US10brow001',
#  'US10brow003',
#  'US10brow004',
#  'US10brow006',
#  'US10buff001',
#  'US10buff002',
#  'US10buff004',
#  'US10buff006',
#  'US10buff007',
#  'US10buff010',
#  'US10buff011',
#  'US10buff012',
#  'US10buff013',
#  'US10buff015',
#  'US10buff017',
#  'US10buff018',
#  'US10buff020',
#  'US10buff025',
#  'US10buff036',
#  'US10burt001',
#  'US10burt003',
#  'US10burt004',
#  'US10butl003',
#  'US10butl004',
#  'US10butl005',
#  'US10butl008',
#  'US10butl013',
#  'US10butl015',
#  'US10butl020',
#  'US10cass001',
#  'US10cass005',
#  'US10cass010',
#  'US10ceda001',
#  'US10ceda002',
#  'US10ceda004',
#  'US10ceda006',
#  'US10ceda008',
#  'US10ceda010',
#  'US10ceda012',
#  'US10ceda013',
#  'US10ceda014',
#  'US10ceda015',
#  'US10ceda017',
#  'US10ceda020',
#  'US10ceda021',
#  'US10ceda026',
#  'US10chas001',
#  'US10chas002',
#  'US10chas010',
#  'US10chas019',
#  'US10chas021',
#  'US10chas024',
#  'US10chas025',
#  'US10chas027',
#  'US10chas028',
#  'US10chas029',
#  'US10chas031',
#  'US10chas034',
#  'US10chas037',
#  'US10chas038',
#  'US10cher005',
#  'US10cher007',
#  'US10cher016',
#  'US10cher025',
#  'US10cher027',
#  'US10cher034',
#  'US10chey003',
#  'US10chey007',
#  'US10chey008',
#  'US10chey010',
#  'US10chey014',
#  'US10chey017',
#  'US10chey019',
#  'US10chey021',
#  'US10chey024',
#  'US10chey025',
#  'US10chey026',
#  'US10chey031',
#  'US10chey034',
#  'US10chey045',
#  'US10chey053',
#  'US10chey060',
#  'US10chey065',
#  'US10clay002',
#  'US10clay004',
#  'US10clay005',
#  'US10clay007',
#  'US10clay008',
#  'US10clay009',
#  'US10clay013',
#  'US10clay015',
#  'US10clay018',
#  'US10clay019',
#  'US10clay021',
#  'US10clay023',
#  'US10clay027',
#  'US10clay029',
#  'US10clay037',
#  'US10clay039',
#  'US10clay041',
#  'US10clay044',
#  'US10colf001',
#  'US10colf002',
#  'US10cumi002',
#  'US10cumi003',
#  'US10cumi006',
#  'US10cumi007',
#  'US10cumi008',
#  'US10cumi009',
#  'US10cumi012',
#  'US10cust001',
#  'US10cust002',
#  'US10cust003',
#  'US10cust007',
#  'US10cust008',
#  'US10cust012',
#  'US10cust028',
#  'US10cust029',
#  'US10cust039',
#  'US10cust041',
#  'US10cust045',
#  'US10dako002',
#  'US10dako003',
#  'US10dawe001',
#  'US10dawe002',
#  'US10dawe003',
#  'US10dawe007',
#  'US10dawe012',
#  'US10dawe016',
#  'US10dawe025',
#  'US10dawe030',
#  'US10daws002',
#  'US10daws003',
#  'US10daws004',
#  'US10daws005',
#  'US10daws006',
#  'US10daws008',
#  'US10daws009',
#  'US10daws010',
#  'US10daws011',
#  'US10daws012',
#  'US10daws013',
#  'US10daws014',
#  'US10daws017',
#  'US10daws018',
#  'US10deue001',
#  'US10deue002',
#  'US10deue003',
#  'US10deue009',
#  'US10deue013',
#  'US10deue015',
#  'US10deue016',
#  'US10deue018',
#  'US10deue025',
#  'US10dixo001',
#  'US10dixo003',
#  'US10dixo005',
#  'US10dodg005',
#  'US10dodg012',
#  'US10doug001',
#  'US10doug002',
#  'US10doug005',
#  'US10doug006',
#  'US10doug007',
#  'US10doug009',
#  'US10doug012',
#  'US10doug013',
#  'US10doug014',
#  'US10doug015',
#  'US10doug018',
#  'US10doug019',
#  'US10doug020',
#  'US10doug021',
#  'US10doug022',
#  'US10doug024',
#  'US10doug025',
#  'US10doug029',
#  'US10doug031',
#  'US10doug033',
#  'US10doug035',
#  'US10doug036',
#  'US10doug046',
#  'US10doug051',
#  'US10doug052',
#  'US10doug053',
#  'US10doug054',
#  'US10doug055',
#  'US10doug057',
#  'US10doug059',
#  'US10doug060',
#  'US10doug064',
#  'US10dund001',
#  'US10dund002',
#  'US10dund005',
#  'US10dund006',
#  'US10dund011',
#  'US10dund014',
#  'US10dund019',
#  'US10fill001',
#  'US10fill002',
#  'US10fill003',
#  'US10fill005',
#  'US10fill006',
#  'US10fill007',
#  'US10fill008',
#  'US10fill010',
#  'US10fill011',
#  'US10fill014',
#  'US10fill015',
#  'US10fill019',
#  'US10fran001',
#  'US10fran002',
#  'US10fran003',
#  'US10fran004',
#  'US10fran005',
#  'US10fran008',
#  'US10fran009',
#  'US10fran013',
#  'US10fran014',
#  'US10fran015',
#  'US10fron002',
#  'US10fron004',
#  'US10fron007',
#  'US10fron008',
#  'US10fron009',
#  'US10furn001',
#  'US10furn002',
#  'US10furn003',
#  'US10furn005',
#  'US10furn008',
#  'US10furn010',
#  'US10furn014',
#  'US10furn015',
#  'US10furn018',
#  'US10furn019',
#  'US10furn020',
#  'US10furn022',
#  'US10furn025',
#  'US10gage001',
#  'US10gage002',
#  'US10gage003',
#  'US10gage007',
#  'US10gage008',
#  'US10gage012',
#  'US10gage013',
#  'US10gage015',
#  'US10gage018',
#  'US10gage020',
#  'US10gage021',
#  'US10gage022',
#  'US10gage023',
#  'US10gage025',
#  'US10gage026',
#  'US10gage033',
#  'US10gage035',
#  'US10gage044',
#  'US10gage045',
#  'US10gard004',
#  'US10gard009',
#  'US10gard011',
#  'US10gard019',
#  'US10gard020',
#  'US10garf001',
#  'US10garf006',
#  'US10garf009',
#  'US10garf010',
#  'US10gran004',
#  'US10gran009',
#  'US10gree002',
#  'US10gree003',
#  'US10gree004',
#  'US10gree007',
#  'US10gree012',
#  'US10hall001',
#  'US10hall002',
#  'US10hall003',
#  'US10hall004',
#  'US10hall005',
#  'US10hall006',
#  'US10hall007',
#  'US10hall008',
#  'US10hall009',
#  'US10hall011',
#  'US10hall012',
#  'US10hall014',
#  'US10hall015',
#  'US10hall016',
#  'US10hall017',
#  'US10hall018',
#  'US10hall021',
#  'US10hall026',
#  'US10hall027',
#  'US10hall035',
#  'US10hall042',
#  'US10hall043',
#  'US10hall044',
#  'US10hami001',
#  'US10hami002',
#  'US10hami003',
#  'US10hami004',
#  'US10hami005',
#  'US10hami006',
#  'US10hami009',
#  'US10hami011',
#  'US10hami012',
#  'US10hami013',
#  'US10hami017',
#  'US10hami019',
#  'US10hami021',
#  'US10harl001',
#  'US10harl002',
#  'US10harl004',
#  'US10harl007',
#  'US10harl008',
#  'US10harl009',
#  'US10harl010',
#  'US10harl014',
#  'US10haye003',
#  'US10haye008',
#  'US10haye012',
#  'US10hitc002',
#  'US10hitc003',
#  'US10hitc005',
#  'US10hitc008',
#  'US10hitc011',
#  'US10hitc012',
#  'US10hitc013',
#  'US10hitc014',
#  'US10hitc015',
#  'US10hitc016',
#  'US10hitc019',
#  'US10hitc020',
#  'US10hitc024',
#  'US10hitc028',
#  'US10holt001',
#  'US10holt002',
#  'US10holt004',
#  'US10holt006',
#  'US10holt007',
#  'US10holt008',
#  'US10holt009',
#  'US10holt010',
#  'US10holt014',
#  'US10holt019',
#  'US10holt024',
#  'US10hook001',
#  'US10hook004',
#  'US10hook008',
#  'US10hook010',
#  'US10howa001',
#  'US10howa003',
#  'US10howa004',
#  'US10howa005',
#  'US10howa010',
#  'US10jeff001',
#  'US10jeff002',
#  'US10jeff003',
#  'US10jeff004',
#  'US10jeff009',
#  'US10jeff011',
#  'US10jeff012',
#  'US10jeff013',
#  'US10jeff014',
#  'US10jeff018',
#  'US10jeff019',
#  'US10jeff020',
#  'US10jeff021',
#  'US10jeff023',
#  'US10jeff025',
#  'US10john001',
#  'US10john002',
#  'US10john003',
#  'US10john004',
#  'US10john005',
#  'US10john006',
#  'US10john007',
#  'US10john008',
#  'US10john009',
#  'US10john010',
#  'US10john012',
#  'US10john014',
#  'US10john016',
#  'US10john017',
#  'US10john020',
#  'US10john021',
#  'US10kear002',
#  'US10kear003',
#  'US10kear004',
#  'US10kear005',
#  'US10kear006',
#  'US10kear008',
#  'US10kear009',
#  'US10kear011',
#  'US10kear013',
#  'US10kear015',
#  'US10kear016',
#  'US10kear019',
#  'US10keit001',
#  'US10keit005',
#  'US10keit007',
#  'US10keit008',
#  'US10keit009',
#  'US10keit011',
#  'US10keit013',
#  'US10keit014',
#  'US10keit015',
#  'US10keit019',
#  'US10keya004',
#  'US10kimb001',
#  'US10kimb002',
#  'US10kimb004',
#  'US10kimb007',
#  'US10kimb008',
#  'US10kimb013',
#  'US10kimb021',
#  'US10kimb025',
#  'US10kimb028',
#  'US10knox003',
#  'US10knox004',
#  'US10knox005',
#  'US10knox009',
#  'US10knox011',
#  'US10knox018',
#  'US10knox019',
#  'US10lanc001',
#  'US10lanc005',
#  'US10lanc006',
#  'US10lanc007',
#  'US10lanc009',
#  'US10lanc011',
#  'US10lanc012',
#  'US10lanc013',
#  'US10lanc016',
#  'US10lanc017',
#  'US10lanc018',
#  'US10lanc019',
#  'US10lanc022',
#  'US10lanc024',
#  'US10lanc025',
#  'US10lanc027',
#  'US10lanc029',
#  'US10lanc030',
#  'US10lanc031',
#  'US10lanc033',
#  'US10lanc034',
#  'US10lanc039',
#  'US10lanc040',
#  'US10lanc041',
#  'US10lanc042',
#  'US10lanc043',
#  'US10lanc047',
#  'US10lanc049',
#  'US10lanc050',
#  'US10lanc052',
#  'US10lanc066',
#  'US10lanc067',
#  'US10lanc068',
#  'US10lanc070',
#  'US10lanc071',
#  'US10lanc072',
#  'US10lanc077',
#  'US10lanc084',
#  'US10linc002',
#  'US10linc006',
#  'US10linc012',
#  'US10linc013',
#  'US10linc015',
#  'US10linc018',
#  'US10linc023',
#  'US10linc031',
#  'US10linc033',
#  'US10linc035',
#  'US10linc036',
#  'US10linc039',
#  'US10linc041',
#  'US10linc048',
#  'US10linc049',
#  'US10linc052',
#  'US10linc054',
#  'US10linc056',
#  'US10linc058',
#  'US10linc060',
#  'US10linc069',
#  'US10loga003',
#  'US10loga004',
#  'US10loga007',
#  'US10madi001',
#  'US10madi002',
#  'US10madi003',
#  'US10madi005',
#  'US10madi006',
#  'US10madi008',
#  'US10madi009',
#  'US10madi010',
#  'US10madi017',
#  'US10madi018',
#  'US10mcph006',
#  'US10merr001',
#  'US10merr002',
#  'US10merr004',
#  'US10merr005',
#  'US10merr007',
#  'US10merr009',
#  'US10merr010',
#  'US10merr011',
#  'US10merr012',
#  'US10merr014',
#  'US10merr015',
#  'US10merr016',
#  'US10merr018',
#  'US10morr006',
#  'US10morr008',
#  'US10morr014',
#  'US10nanc001',
#  'US10nanc004',
#  'US10nema001',
#  'US10nema002',
#  'US10nema004',
#  'US10nema005',
#  'US10nema006',
#  'US10nema007',
#  'US10nema008',
#  'US10nema009',
#  'US10nema010',
#  'US10nema012',
#  'US10nema013',
#  'US10nema014',
#  'US10nuck001',
#  'US10nuck002',
#  'US10nuck003',
#  'US10nuck004',
#  'US10nuck006',
#  'US10nuck007',
#  'US10nuck008',
#  'US10nuck013',
#  'US10nuck017',
#  'US10nuck018',
#  'US10nuck019',
#  'US10nuck020',
#  'US10nuck021',
#  'US10nuck022',
#  'US10nuck023',
#  'US10nuck024',
#  'US10nuck026',
#  'US10nuck027',
#  'US10nuck028',
#  'US10nuck030',
#  'US10nuck034',
#  'US10nuck035',
#  'US10otoe001',
#  'US10otoe002',
#  'US10otoe003',
#  'US10otoe004',
#  'US10otoe005',
#  'US10otoe006',
#  'US10otoe007',
#  'US10otoe008',
#  'US10otoe009',
#  'US10otoe010',
#  'US10otoe011',
#  'US10otoe012',
#  'US10otoe013',
#  'US10otoe014',
#  'US10otoe015',
#  'US10otoe016',
#  'US10otoe017',
#  'US10otoe019',
#  'US10otoe026',
#  'US10otoe027',
#  'US10otoe028',
#  'US10otoe030',
#  'US10pawn002',
#  'US10pawn003',
#  'US10pawn004',
#  'US10pawn006',
#  'US10pawn007',
#  'US10pawn008',
#  'US10pawn009',
#  'US10pawn010',
#  'US10pawn013',
#  'US10perk002',
#  'US10perk004',
#  'US10perk005',
#  'US10perk006',
#  'US10perk009',
#  'US10perk013',
#  'US10perk014',
#  'US10perk015',
#  'US10perk016',
#  'US10perk017',
#  'US10perk021',
#  'US10perk032',
#  'US10perk034',
#  'US10perk036',
#  'US10perk037',
#  'US10phel001',
#  'US10phel002',
#  'US10phel003',
#  'US10phel007',
#  'US10phel008',
#  'US10phel011',
#  'US10phel014',
#  'US10phel015',
#  'US10pier002',
#  'US10pier005',
#  'US10pier007',
#  'US10pier009',
#  'US10pier010',
#  'US10pier011',
#  'US10plat003',
#  'US10plat004',
#  'US10plat012',
#  'US10plat013',
#  'US10plat014',
#  'US10plat020',
#  'US10plat022',
#  'US10plat025',
#  'US10polk001',
#  'US10polk002',
#  'US10polk003',
#  'US10polk005',
#  'US10polk006',
#  'US10polk012',
#  'US10polk013',
#  'US10polk014',
#  'US10polk015',
#  'US10red_002',
#  'US10red_003',
#  'US10red_005',
#  'US10red_006',
#  'US10red_007',
#  'US10red_008',
#  'US10red_012',
#  'US10red_013',
#  'US10red_014',
#  'US10red_017',
#  'US10red_018',
#  'US10red_019',
#  'US10red_020',
#  'US10red_022',
#  'US10red_023',
#  'US10red_024',
#  'US10rich001',
#  'US10rich003',
#  'US10rich005',
#  'US10rich010',
#  'US10rich012',
#  'US10rich015',
#  'US10rich016',
#  'US10rich017',
#  'US10rock001',
#  'US10rock003',
#  'US10sali003',
#  'US10sali004',
#  'US10sali005',
#  'US10sali007',
#  'US10sali008',
#  'US10sali010',
#  'US10sali011',
#  'US10sali015',
#  'US10sali016',
#  'US10sali019',
#  'US10sali021',
#  'US10sali023',
#  'US10sali024',
#  'US10sali030',
#  'US10sali031',
#  'US10sarp002',
#  'US10sarp004',
#  'US10sarp005',
#  'US10sarp006',
#  'US10sarp007',
#  'US10sarp008',
#  'US10sarp009',
#  'US10sarp011',
#  'US10sarp012',
#  'US10sarp014',
#  'US10sarp015',
#  'US10sarp016',
#  'US10sarp017',
#  'US10sarp018',
#  'US10sarp020',
#  'US10sarp022',
#  'US10sarp024',
#  'US10sarp028',
#  'US10sarp029',
#  'US10sarp031',
#  'US10sarp032',
#  'US10sarp035',
#  'US10sarp036',
#  'US10sarp038',
#  'US10sarp039',
#  'US10sarp048',
#  'US10sarp049',
#  'US10saun002',
#  'US10saun005',
#  'US10saun008',
#  'US10saun009',
#  'US10saun012',
#  'US10saun014',
#  'US10scot003',
#  'US10scot005',
#  'US10scot006',
#  'US10scot008',
#  'US10scot011',
#  'US10scot013',
#  'US10scot014',
#  'US10scot016',
#  'US10scot017',
#  'US10scot019',
#  'US10scot022',
#  'US10scot023',
#  'US10scot026',
#  'US10scot027',
#  'US10scot034',
#  'US10scot039',
#  'US10scot041',
#  'US10sewa002',
#  'US10sewa004',
#  'US10sewa005',
#  'US10sewa006',
#  'US10sewa007',
#  'US10sewa009',
#  'US10sewa010',
#  'US10sewa011',
#  'US10sewa013',
#  'US10sewa014',
#  'US10sewa015',
#  'US10sewa016',
#  'US10sewa017',
#  'US10sewa020',
#  'US10sewa021',
#  'US10sewa022',
#  'US10sewa023',
#  'US10shem001',
#  'US10shem003',
#  'US10shem008',
#  'US10shem009',
#  'US10shem011',
#  'US10shem012',
#  'US10shem016',
#  'US10sher002',
#  'US10sher004',
#  'US10sher017',
#  'US10sher019',
#  'US10sher026',
#  'US10sher032',
#  'US10siou001',
#  'US10stan003',
#  'US10stan006',
#  'US10stan007',
#  'US10stan008',
#  'US10stan010',
#  'US10stan013',
#  'US10thay001',
#  'US10thay002',
#  'US10thay003',
#  'US10thay004',
#  'US10thay005',
#  'US10thay006',
#  'US10thay008',
#  'US10thay009',
#  'US10thay010',
#  'US10thay011',
#  'US10thay013',
#  'US10thay015',
#  'US10thay017',
#  'US10thay018',
#  'US10thay019',
#  'US10thay020',
#  'US10thay021',
#  'US10thay023',
#  'US10thay026',
#  'US10thay027',
#  'US10thom002',
#  'US10thom003',
#  'US10thom006',
#  'US10thom009',
#  'US10thom012',
#  'US10thom014',
#  'US10thur002',
#  'US10vall001',
#  'US10vall003',
#  'US10vall005',
#  'US10vall006',
#  'US10vall007',
#  'US10vall009',
#  'US10vall010',
#  'US10vall012',
#  'US10vall015',
#  'US10vall018',
#  'US10vall020',
#  'US10wash001',
#  'US10wash003',
#  'US10wash004',
#  'US10wash006',
#  'US10wash011',
#  'US10wash012',
#  'US10wash014',
#  'US10wayn001',
#  'US10wayn002',
#  'US10wayn003',
#  'US10wayn006',
#  'US10wayn007',
#  'US10wayn008',
#  'US10webs001',
#  'US10webs002',
#  'US10webs003',
#  'US10webs004',
#  'US10webs005',
#  'US10webs007',
#  'US10webs008',
#  'US10webs009',
#  'US10webs010',
#  'US10webs013',
#  'US10webs015',
#  'US10webs018',
#  'US10webs019',
#  'US10webs020',
#  'US10webs021',
#  'US10webs022',
#  'US10whee009',
#  'US10york002',
#  'US10york003',
#  'US10york008',
#  'US10york009',
#  'US10york010',
#  'US10york011',
#  'US10york015',
#  'US10york017',
#  'US10york018',
#  'US10york019',
#  'US10york020',
#  'US10york022',
#  'US10york024',
#  'US10york025',
#  'US10york026',
#  'US10york027',
#  'US10york028',
#  'US10york029',
#  'US10york033',
#  'US10york034',
#  'US10york035',
#  'US10york036',
#  'US10york037',
#  'US10york039',
#  'US10york040',
#  'US10york041',
#  'US10york042',
#  'US10york044',
#  'US10york045',
#  'US1AKAB0001',
#  'US1AKAB0003',
#  'US1AKAB0004',
#  'US1AKAB0006',
#  'US1AKAB0007',
#  'US1AKAB0009',
#  'US1AKAB0014',
#  'US1AKAB0015',
#  'US1AKAB0021',
#  'US1AKAB0027',
#  'US1AKAB0028',
#  'US1AKAB0030',
#  'US1AKAB0036',
#  'US1AKAB0051',
#  'US1AKAB0052',
#  'US1AKAB0055',
#  'US1AKAB0058',
#  'US1AKAB0060',
#  'US1AKAB0061',
#  'US1AKAB0062',
#  'US1AKAB0065',
#  'US1AKFN0004',
#  'US1AKFN0016',
#  'US1AKFN0030',
#  'US1AKJB0005',
#  'US1AKJB0007',
#  'US1AKJB0009',
#  'US1AKJB0010',
#  'US1AKKP0002',
#  'US1AKKP0005',
#  'US1AKMS0011',
#  'US1AKMS0014',
#  'US1AKMS0020',
#  'US1ALAT0002',
#  'US1ALAT0010',
#  'US1ALAT0013',
#  'US1ALAT0014',
#  'US1ALBB0003',
#  'US1ALBB0004',
#  'US1ALBB0005',
#  'US1ALBB0006',
#  'US1ALBB0008',
#  'US1ALBL0002',
#  'US1ALBL0005',
#  'US1ALBL0006',
#  'US1ALBL0008',
#  'US1ALBL0009',
#  'US1ALBL0015',
#  'US1ALBL0016',
#  'US1ALBL0018',
#  'US1ALBL0020',
#  'US1ALBL0023',
#  'US1ALBR0001',
#  'US1ALBR0002',
#  'US1ALBR0003',
#  'US1ALBT0001',
#  'US1ALBW0001',
#  'US1ALBW0003',
#  'US1ALBW0004',
#  'US1ALBW0005',
#  'US1ALBW0008',
#  'US1ALBW0009',
#  'US1ALBW0011',
#  'US1ALBW0013',
#  'US1ALBW0015',
#  'US1ALBW0017',
#  'US1ALBW0019',
#  'US1ALBW0020',
#  'US1ALBW0023',
#  'US1ALBW0026',
#  'US1ALBW0027',
#  'US1ALBW0028',
#  'US1ALBW0030',
#  'US1ALBW0031',
#  'US1ALBW0032',
#  'US1ALBW0033',
#  'US1ALBW0035',
#  'US1ALBW0036',
#  'US1ALBW0038',
#  'US1ALBW0039',
#  'US1ALBW0040',
#  'US1ALBW0041',
#  'US1ALBW0042',
#  'US1ALBW0043',
#  'US1ALBW0045',
#  'US1ALBW0049',
#  'US1ALBW0052',
#  'US1ALBW0053',
#  'US1ALBW0054',
#  'US1ALBW0057',
#  'US1ALBW0058',
#  'US1ALBW0060',
#  'US1ALBW0065',
#  'US1ALBW0066',
#  'US1ALBW0068',
#  'US1ALBW0071',
#  ...]

# %% [markdown]
# For each weather station, call the API to get the correct csv files.
#
# E.g. `https://www.ncei.noaa.gov/data/global-summary-of-the-month/access/ACW00011647.csv`
#
# **Warning:** Takes avg 74 mins to get all files.

# %%
from concurrent.futures import ThreadPoolExecutor
import requests


def generate_dl_kwargs(limit: int = None):
    return [
        us_station
        for us_station in us_stations_all_zip.station_id.to_list()
    ][:limit]


def download_file(us_station: str):
    filename = f"{us_station}.csv"
    url = f"https://www.ncei.noaa.gov/data/global-summary-of-the-month/access/{filename}"
    print(f"Downloading csv file from {url}")
    response = requests.get(url)
    if str(response.status_code).startswith(('4', '5')):
        print(f"Failed to download file {filename}")
    else:
        with open(f"artifacts/access/{filename}", mode="wb") as file:
            file.write(response.content)
        print(f"Downloaded file {filename}")

# Commented out, don't download again
# with ThreadPoolExecutor(max_workers=10) as executor:
#     executor.map(download_file, generate_dl_kwargs())

# %% [markdown]
# Filter 2015 - 2023. Stitch all csv files together.

# %%
# Commented out, don't write again
import pathlib

all_csvs = pathlib.Path('artifacts/access').glob("*.csv")
us_data = pd.concat([pd.read_csv(c) for c in all_csvs], ignore_index=True)

# %%
us_data['DATE'] = pd.to_datetime(us_data['DATE'], errors="ignore")
us_data_filtered_df = us_data[us_data['DATE'].dt.year >= 2015]
# Out:
# /var/folders/44/y4yg1dfd20sg9qvqvp_3djc40000gn/T/ipykernel_32653/2213275545.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   us_data['DATE'] = pd.to_datetime(us_data['DATE'], errors="ignore")

# %%
us_data_filtered_df
# Out:
#              STATION       DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 0        US1MDFR0038 2019-08-01  39.419264 -77.430926      100.0
# 1        US1MDFR0038 2019-09-01  39.419264 -77.430926      100.0
# 2        US1MDFR0038 2019-10-01  39.419264 -77.430926      100.0
# 3        US1MDFR0038 2019-12-01  39.419264 -77.430926      100.0
# 4        US1MDFR0038 2020-01-01  39.419264 -77.430926      100.0
# ...              ...        ...        ...        ...        ...
# 9420654  US1MIHG0017 2017-12-01  47.253000 -88.446521      368.2
# 9420655  US1MIHG0017 2018-01-01  47.253000 -88.446521      368.2
# 9420656  US1MIHG0017 2019-01-01  47.253000 -88.446521      368.2
# 9420657  US1MIHG0017 2019-02-01  47.253000 -88.446521      368.2
# 9420658  US1MIHG0017 2019-11-01  47.253000 -88.446521      368.2
#
#                                        NAME  DP01 DP01_ATTRIBUTES  DP10  \
# 0                   FREDERICK 1.0 SW, MD US   9.0              ,N   5.0
# 1                   FREDERICK 1.0 SW, MD US   5.0              ,N   3.0
# 2                   FREDERICK 1.0 SW, MD US  12.0              ,N  10.0
# 3                   FREDERICK 1.0 SW, MD US  14.0             1,N   8.0
# 4                   FREDERICK 1.0 SW, MD US  11.0              ,N   6.0
# ...                                     ...   ...             ...   ...
# 9420654  CALUMET 0.5 NE CALUMET LAKE, MI US   NaN             NaN   NaN
# 9420655  CALUMET 0.5 NE CALUMET LAKE, MI US   NaN             NaN   NaN
# 9420656  CALUMET 0.5 NE CALUMET LAKE, MI US   NaN             NaN   NaN
# 9420657  CALUMET 0.5 NE CALUMET LAKE, MI US   NaN             NaN   NaN
# 9420658  CALUMET 0.5 NE CALUMET LAKE, MI US   NaN             NaN   NaN
#
#         DP10_ATTRIBUTES  ...  MX05 MX05_ATTRIBUTES  MX06 MX06_ATTRIBUTES  \
# 0                    ,N  ...   NaN             NaN   NaN             NaN
# 1                    ,N  ...   NaN             NaN   NaN             NaN
# 2                    ,N  ...   NaN             NaN   NaN             NaN
# 3                   1,N  ...   NaN             NaN   NaN             NaN
# 4                    ,N  ...   NaN             NaN   NaN             NaN
# ...                 ...  ...   ...             ...   ...             ...
# 9420654             NaN  ...   NaN             NaN   NaN             NaN
# 9420655             NaN  ...   NaN             NaN   NaN             NaN
# 9420656             NaN  ...   NaN             NaN   NaN             NaN
# 9420657             NaN  ...   NaN             NaN   NaN             NaN
# 9420658             NaN  ...   NaN             NaN   NaN             NaN
#
#          MX07 MX07_ATTRIBUTES  MX08 MX08_ATTRIBUTES  MX09 MX09_ATTRIBUTES
# 0         NaN             NaN   NaN             NaN   NaN             NaN
# 1         NaN             NaN   NaN             NaN   NaN             NaN
# 2         NaN             NaN   NaN             NaN   NaN             NaN
# 3         NaN             NaN   NaN             NaN   NaN             NaN
# 4         NaN             NaN   NaN             NaN   NaN             NaN
# ...       ...             ...   ...             ...   ...             ...
# 9420654   NaN             NaN   NaN             NaN   NaN             NaN
# 9420655   NaN             NaN   NaN             NaN   NaN             NaN
# 9420656   NaN             NaN   NaN             NaN   NaN             NaN
# 9420657   NaN             NaN   NaN             NaN   NaN             NaN
# 9420658   NaN             NaN   NaN             NaN   NaN             NaN
#
# [1551078 rows x 227 columns]

# %%
us_data_filtered_df.to_csv(
    "artifacts/us_data.csv",
    index=False
)

# %%
us_stations_all_zip.to_csv(
    "artifacts/us_data_all_zip.csv",
    index=False
)
